# %% [markdown]
# # 6. Скалярное произведение в ортонормированном базисе. Существование ортонормированного базиса.

# %% [markdown]
# Понятия, которые следует упомянуть, но мне лень расписывать: ортогональность векторов, ортогональность вектора подпространству ($ x \perp L $), ортогональность подпространств ($ L_1 \perp L_2 $), ортогональная система, ортонормированная система.

# %% [markdown]
# ### Теорема 70.1
#
# Ортогональная система ненулевых векторов линейно независива.
#
# ### Доказательство
#
# Полагаем, что она зависима, записываем эту систему с коэффиценами такими, чтобы линейная комбинация была равна нулю, и умножаем её на $ x_i $. Получем $ \alpha (x_i, x_i) = 0 \Rightarrow x_i = \theta $, что противоречит условию.

# %% [markdown]
# Следствия:
# 1. Любая ортонормированная система векторов линейно независима
# 2. В n-мерном пространстве любая ортонормированная система из $ n $ векторов является базисом.

# %% [markdown]
# ### Теорема 70.2
#
# В евклидовом (унитарном) пространстве координаты вектора $ x $ в базисе $ e_1, \dots, e_n $ вычисляются по правилу $$ x_i = (x, e_i), \space i = \overline{1, n} $$ тогда и только тогда, когда бозис $ e $ - ортонормированный.
#
# ### Доказательство
#
# Необходимость. Допустим координаты вычисляются по данному правилу. Тогда и координаты базисных векторов вычисляются так же $ e_i = 0e_1 + \dots + 0e_{i - 1} + 1e_i + 0e_{i + 1}, \dots, 0e_n \Rightarrow 1 = (e_i, e_i), \space i = \overline{1, n} $
# Достаточность. Представим $ x $ как линейную комбинацию базисных векторов и домножи её на $ e_i $ в силу линейности, правило выполняется
#
# Profit

# %% [markdown]
# ### Теорема 70.3
#
# В евклидовом (унитарном) пространстве скалярное произведение векторов $ x = \sum_{i = 1}^n x_i e_i, y = \sum_{i = 1}^n y_i e_i $ вычисляется по правилу $$ (x, y) = \sum\limits_{i = 1}^n x_i \overline y_i $$ тогда и только тогда, когда $ e $ - ортонормированный базис.
#
# ### Доказаьтельство
#
# Необходимость. Применим это правило к произведению базисных векторов, получим $ (e_i, e_j) = \begin{cases} 1, i = j \newline 0, i \neq j \end{cases} $, то есть базис $ e $ ортонормирован.
# Достаточность. $ (x, y) = (\sum_{i = 1}^n x_i e_i, \sum_{i = 1}^n y_i e_i) = \sum_{i = 1}^n \sum_{j = 1}^n x_i \overline y_j (e_i, e_j) = \sum_{i = 1}^n x_i \overline y_i $

# %% [markdown]
# ### Теорема 70.4
#
# В конечномерном евклидовом (унитарном) пространстве существует ортонормированный базис.
#
# ### Доказательство
#
# Пусть $ \dim V = n $. Используем индукцию по $ n $. Пусть в любом евклидовом подпространстве размерности $ n - 1 $ существует ортонормированный базис. Покажем, что ортонормированный базис существует и в пространстве размерности $ n $. Рассмотрим базис пространства размерности $ n \space f_1, \dots, f_n $, возьмём подпространство $ L(f_1, \dots, f_{n - 1}) $, для него зададим ортонормированный базис $ e_1, \dots, e_{n - 1} $. Потом зададим вектор $ g_n = f_n - \alpha_1 e_1 - \dots - \alpha_{n - 1} e_{n - 1} $. Положим $ 0 = (g_n, e_i) = (f_n - e_i) - \alpha_i, \space i = \overline{1, n} $. Базис $ e_1, \dot, e_{n - 1}, g_n $ ортогонален. Теперь положим $ e_n = \frac{g_n}{|g_n|} $. Мы получили ортонормированный базис.
#
# Profit
