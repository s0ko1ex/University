# %% [markdown]
# # 23. Инвариантные подпространства минимальной размерности (в комплексном и вещественном пространствах)

# %% [markdown]
# ### Теорема 1
#
# Произвольный линейный оператор, действующий в комплексном пространстве, на любом своём инвариантном подпространстве имеет хотя бы один собственный вектор.
#
# ### Доказательство
#
# Вытекает из теоремы 86.1 о то, что $ \lambda \in P $ является собственным значением оператора тогда и только тогда, когда $ \lambda $ - корень характеристического многочлена.

# %% [markdown]
# ### Теорема 93.1
#
# У всякого линейного оператора, действующего в комплексном пространстве, существует одномерное инвариантное подпространство.
#
# ### Доказательство
#
# Порождаемое существующим собственным вектором.

# %% [markdown]
# ### Теорема 93.2
#
# У всякого линейного оператора, действующего в вещественном пространстве, существует одномерное или двумерное инвариантное подпространство.
#
# ### Доказательство
#
# Первое верно в случае, когда есть вещественный корень характеристического многочлена.
# Если $ \lambda = \alpha + \beta i, x = u + wi $, то $ L = \mathcal L (u, w) $ - двумерное инвариантное подпространство.

# %% [markdown]
# ### Теорема 89.1
#
# В $ n $-мерном комплекном пространстве для любого линейного оператора $ \mathcal{A \in L}(V, V) $ существует система $ n $ вложенных друг в друга инвариантных подпространств $ L_1, \dots, L_n $ всех размерностей от $ 1 $ до $ n $, т.е.
#
# $$ L_1 \subset L_2 \subset \dots \subset L_n = V $$
#
# где $ \dim L_k = k, \space k = \overline{1, n} $
#
# ### Доказательство
#
# Для $ n = 1 $ это очевидно, докажем индукцией по $ n $. Допустим это верно для $ n - 1 $. Тогда $ \exists L_{n - 1}: \space \dim L_{n - 1} = n - 1 $ ($ \dim \text{im} \space (\mathcal A - \lambda I) \leq n - 1 $, говорим, что есть подпространство размерности $n$, содержащее данный образ и то, что оно инвариантно). Оператор $ \mathcal A | L_{n - 1} $ по предположению индукции имеет вложенные подпространства $ L_1 \subset L_2 \subset \dots \subset L_{n - 1} $ и $ L_{n - 1} \subset L_n = V $.
#
# Profit.
