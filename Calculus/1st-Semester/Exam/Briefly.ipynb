# %% [markdown]
# ### 1
#
# - аксиомы
# - понятие на отрезке
# - определение вещественного
# - определение операций
# - ограниченное множество
# - точные границы
# - принцип полноты Вейерштрасса
#
# ### 2
#
# - внесение бесконечного числа рационыльных между двумя различными вещественными
# - зажимание между двумя рациональными
# - равенство зажатых
# - сумма, произведение: корректность, единственность
#
# ### 3
#
# - понятие множества :)
# - операции (объединение, пересечение)
# - мощность
# - эквивалентность
# - счётное, несчётное множества, их неэквивалентность
# - подмножество счётного множества
#
# ### 4
#
# - понятие последовательности
# - ограниченность сверху, снизу, везде, неограниченные в развитии
# - ББП, БМП
# - их свойства (основных 5)
#
# ### 5
#
# - сходящаяся последовательность, её предел, 2 определения
# - окрестность
# - теоремы о единственности предела, об ограниченности сходящейся, об операциях
#
# ### 6
#
# - предельный переход, следствия
# - монотонная последовательность
# - сходимость монотонной ограниченной последовательности
# - бином, неравенство Бернулли
# - число $ e $, последовательности
# - ограниченность
# - одна последовательность - возрастающая, другая - убывающая
#
# ### 7
#
# - подпоследовательность, предельная точка как предел подпоследовательности, как бесконечность точек в эпсилон-окрестности
# - равенство пределов последовательности и подпоследовательности
# - если любая подпоследовательность сходится, то и вся последовательность сходится
# - верхний, нижний пределы
# - ограниченная последовательность имеет верхний и нижний пределы и одну предельную точку
# - Больцано-Вейерштрасс - выделение сходящейся подпоследовательности из ограниченной
# - Границы последовательности
# - эквивалентность сходимости равенству верхнего, нижнего пределов
#
# ### 8
#
# - предел - элемент
# - ограниченность
# - сходящаяся = фундаментальная
# - отрицание
#
# ### 9
#
# - эквивалентность
# - определения на бесконечности
# - предел справа, слева
# - критерий коши эквивалентен существованию конечного предела
