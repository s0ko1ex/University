# %% [markdown]
# $ cos \sqrt{x} \in [-1, 1] $
#
# $ \sqrt{cos x} \in [0, 1] $

# %% [markdown]
# \begin{theorem) Suppose $a \leq b \leq c$ are the side-lengths of a right triangle.<br> Then $a^2 + b^2 = c^2$.\end{theorem}
